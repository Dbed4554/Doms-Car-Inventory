# %%
#aesthetics!!!
print("Welcome to Catch a ride inventory Code!")
x = input("To get started please select whether to search by Vehicle ID or Make and Model!")
if x = "vehicle ID" or x = "ID":
    y = input("Please enter vehicle Identification:")
elif x = "Make and Model" or x = "Make" or x = "Model":
    
import pandas as pd
cars = pd.read_excel("Cars.xls")
df = pd.DataFrame(cars)
# Out:
#     Vehicle Identification Number (if applicable)  \
# 0                               1J4GL48K26W141719
# 1                              J8DE5B167779005000
# 2                              J8DE5B168779903793
# 3                               J8DC4B14437010491
# 4                                         2111412
# 5                                         2111399
# 6                               2W9MNH6136S044232
# 7                                2W9MNH611S044231
# 8                                1GTCS4H638278467
# 9                               1J4GL48K16W102376
# 10                              1G1BL5164JR173283
# 11                               1FDNF70K1KV25196
# 12                              1FTYR11U86PA67221
# 13                              1FDWF36F6XED43619
# 14                             1FMZU34E8WU1360790
# 15                              1FTYR11U66PA67220
# 16                              1FTNF21F5XEC95709
# 17                               J4FA49S8YP740072
# ...
